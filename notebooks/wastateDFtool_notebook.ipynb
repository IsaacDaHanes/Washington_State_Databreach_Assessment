# %%
# autoreload
# %load_ext autoreload
# %autoreload 2

# %%
# in your notebook cell
import sys

# path relative to your notebook
sys.path.insert(0, '../src')

# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
import wastateDFtool as wa

# %%
Databreaches = wa.WaStateDBDF('../data/wa_state_data_breaches.csv')
# Out:
# c:\Users\RGBMonster\galvanize\daimil10\case_studies\Mid_Term_Repos\Washington_State_Databreach_Assessment\notebooks\../src\wastateDFtool.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Databreaches.cleandf
# Out:
# c:\Users\RGBMonster\galvanize\daimil10\case_studies\Mid_Term_Repos\Washington_State_Databreach_Assessment\notebooks\../src\wastateDFtool.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       DateAware DateSubmitted      DataBreachCause   DateStart     DateEnd  \
# 0    2018-03-28    2018-04-11          Cyberattack  2017-09-26  2017-10-12
# 1    2018-03-28    2018-04-13          Cyberattack  2017-09-26  2017-10-12
# 2    2018-03-14    2018-04-13  Unauthorized Access         NaT         NaT
# 3    2018-03-15    2018-04-24          Cyberattack  2017-09-27  2017-10-12
# 4    2018-03-29    2018-04-26          Cyberattack  2017-07-01  2018-03-31
# ..          ...           ...                  ...         ...         ...
# 940  2023-05-30    2023-08-25  Unauthorized Access  2023-05-27  2023-05-31
# 941  2023-06-09    2023-09-25          Cyberattack  2023-06-09         NaT
# 942  2023-06-04    2023-09-25  Unauthorized Access         NaT         NaT
# 943  2023-05-31    2023-09-22          Cyberattack  2023-05-30  2023-05-31
# 944  2021-12-06    2022-08-19  Unauthorized Access  2021-10-27  2021-12-07
#
#                                           Name CyberattackType  \
# 0                               Delta Airlines         Malware
# 1                            Best Buy Co, Inc.         Malware
# 2                                  Inogen Inc.             NaN
# 3                               Sears Holdings         Malware
# 4                         Hudson's Bay Company         Malware
# ..                                         ...             ...
# 940                              Maximus, Inc.             NaN
# 941              Spinal and Sports Care Clinic      Ransomware
# 942                      Data Media Associates             NaN
# 943  Financial Institution Service Corporation           Other
# 944               Community Loan Servicing LLC             NaN
#
#      WashingtoniansAffected IndustryType           BusinessType  \
# 0                     24563     Business               Software
# 1                      8390     Business                 Retail
# 2                       518       Health                    NaN
# 3                      2373     Business                 Retail
# 4                       NaN     Business                 Retail
# ..                      ...          ...                    ...
# 940                   23374     Business           Web Services
# 941                    1089       Health                    NaN
# 942                     657     Business  Professional Services
# 943                    2140      Finance                    NaN
# 944                    7518      Finance                    NaN
#
#     WashingtoniansAffectedRange BreachLifecycleRange  DaysToContainBreach  \
# 0                 10,000-49,999              100-199                    0
# 1                   1,000-9,999              100-199                    0
# 2                       500-999              Unknown                  NaN
# 3                   1,000-9,999              100-199                    0
# 4                       Unknown              200-299                    2
# ..                          ...                  ...                  ...
# 940               10,000-49,999                 1-99                    1
# 941                 1,000-9,999              Unknown                  NaN
# 942                     500-999              Unknown                  NaN
# 943                 1,000-9,999                 1-99                    0
# 944                 1,000-9,999                 1-99                    1
#
#      DaysToIdentifyBreach  DaysBreachLifecycle  DiscoveredInProgress  \
# 0                     183                  183                 False
# 1                     183                  183                 False
# 2                     NaN                  NaN                 False
# 3                     169                  169                 False
# 4                     271                  273                  True
# ..                    ...                  ...                   ...
# 940                     3                    4                  True
# 941                     0                  NaN                 False
# 942                   NaN                  NaN                 False
# 943                     1                    1                  True
# 944                    40                   41                  True
#
#      DaysOfExposure  DaysElapsedBetweenEndAndDiscovery  \
# 0                16                                167
# 1                16                                167
# 2               NaN                                NaN
# 3                15                                154
# 4               273                                NaN
# ..              ...                                ...
# 940               4                                NaN
# 941             NaN                                NaN
# 942             NaN                                NaN
# 943               1                                NaN
# 944              41                                NaN
#
#      DaysElapsedBeforeNotification DaysOfExposureRange
# 0                               14                1-99
# 1                               16                1-99
# 2                               30             Unknown
# 3                               40                1-99
# 4                               28             200-299
# ..                             ...                 ...
# 940                             87                1-99
# 941                            108             Unknown
# 942                            113             Unknown
# 943                            114                1-99
# 944                            256                1-99
#
# [945 rows x 20 columns]

# %%
Databreaches.get_data_stats('s')
# Out:
# c:\Users\RGBMonster\galvanize\daimil10\case_studies\Mid_Term_Repos\Washington_State_Databreach_Assessment\notebooks\../src\wastateDFtool.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\RGBMonster\galvanize\daimil10\case_studies\Mid_Term_Repos\Washington_State_Databreach_Assessment\notebooks\../src\wastateDFtool.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Databreaches.get_data_stats('o')
# Out:
# c:\Users\RGBMonster\galvanize\daimil10\case_studies\Mid_Term_Repos\Washington_State_Databreach_Assessment\notebooks\../src\wastateDFtool.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\RGBMonster\galvanize\daimil10\case_studies\Mid_Term_Repos\Washington_State_Databreach_Assessment\notebooks\../src\wastateDFtool.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Databreaches.columnlist
# Out:
# array(['DateAware', 'DateSubmitted', 'DataBreachCause', 'DateStart',
#        'DateEnd', 'Name', 'CyberattackType', 'WashingtoniansAffected',
#        'IndustryType', 'BusinessType', 'WashingtoniansAffectedRange',
#        'BreachLifecycleRange', 'DaysToContainBreach',
#        'DaysToIdentifyBreach', 'DaysBreachLifecycle',
#        'DiscoveredInProgress', 'DaysOfExposure',
#        'DaysElapsedBetweenEndAndDiscovery',
#        'DaysElapsedBeforeNotification', 'DaysOfExposureRange'],
#       dtype=object)

# %%
Databreaches.get_vcount('DiscoveredInProgress')
# Out:
# c:\Users\RGBMonster\galvanize\daimil10\case_studies\Mid_Term_Repos\Washington_State_Databreach_Assessment\notebooks\../src\wastateDFtool.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# False    576
# True     369
# Name: DiscoveredInProgress, dtype: int64

# %%
Databreaches.get_uniques('CyberattackType')
# Out:
# c:\Users\RGBMonster\galvanize\daimil10\case_studies\Mid_Term_Repos\Washington_State_Databreach_Assessment\notebooks\../src\wastateDFtool.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array(['Malware', nan, 'Unreported', 'Phishing', 'Skimmers', 'Ransomware',
#        'Other', 'Unclear/unknown'], dtype=object)
